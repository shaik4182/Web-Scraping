# %%
import requests
from bs4 import BeautifulSoup
import pprint

res = requests.get('https://news.ycombinator.com/news')
res2 = requests.get('https://news.ycombinator.com/news?p=2')
soup = BeautifulSoup(res.text, 'html.parser')
soup2 = BeautifulSoup(res2.text, 'html.parser')

links = soup.select('.storylink')
subtext = soup.select('.subtext')
links2 = soup2.select('.storylink')
subtext2 = soup2.select('.subtext')

mega_links = links + links2
mega_subtext = subtext + subtext2

def sort_stories_by_votes(hnlist):
  return sorted(hnlist, key= lambda k:k['votes'], reverse=True)

def create_custom_hn(links, subtext):
  hn = []
  for idx, item in enumerate(links):
    title = item.getText()
    href = item.get('href', None)
    vote = subtext[idx].select('.score')
    if len(vote):
      points = int(vote[0].getText().replace(' points', ''))
      if points > 99:
        hn.append({'title': title, 'link': href, 'votes': points})
  return sort_stories_by_votes(hn)
 
pprint.pprint(create_custom_hn(mega_links, mega_subtext))
# Out:
# [{'link': 'https://www.bleepingcomputer.com/news/software/seti-home-search-for-alien-life-project-shuts-down-after-21-years/',
#   'title': 'SETI@home shuts down after 21 years',
#   'votes': 1150},
#  {'link': 'https://www.courdecassation.fr/IMG/20200304_arret_uber_communique_eng.pdf?',
#   'title': 'Highest French court reclassifies Uber drivers as employees',
#   'votes': 663},
#  {'link': 'http://spotthedrowningchild.com/#',
#   'title': 'Spot the Drowning Child (2015)',
#   'votes': 635},
#  {'link': 'https://cloud.google.com/kubernetes-engine/pricing',
#   'title': 'Google Kubernetes Engine is introducing a cluster management fee '
#            'on June 6',
#   'votes': 512},
#  {'link': 'https://www.law.nyu.edu/centers/engelberg/news/2020-03-04-youtube-takedown',
#   'title': 'Explaining copyright broke the YouTube copyright system',
#   'votes': 438},
#  {'link': 'https://georgestocker.com/2020/03/04/please-stop-recommending-git-flow/',
#   'title': 'Please stop recommending Gitflow',
#   'votes': 314},
#  {'link': 'https://www.quantamagazine.org/landmark-computer-science-proof-cascades-through-physics-and-math-20200304/',
#   'title': 'Landmark computer science proof cascades through physics and math',
#   'votes': 297},
#  {'link': 'https://waymo.com/waymo-via/', 'title': 'Waymo Via', 'votes': 284},
#  {'link': 'https://techcrunch.com/2020/03/04/anthony-levandowski-ordered-to-pay-179-million-to-google/',
#   'title': 'Anthony Levandowski ordered to pay $179M to Google',
#   'votes': 280},
#  {'link': 'https://monitoror.com',
#   'title': 'Show HN: Monitoror – Unified monitoring wallboard',
#   'votes': 271},
#  {'link': 'https://africafeeds.com/2020/02/27/malawi-legalises-the-growing-selling-and-export-of-cannabis/',
#   'title': 'Malawi legalises the growing, selling and export of cannabis',
#   'votes': 216},
#  {'link': 'https://www.youtube.com/watch?v=F8JCh0owT4w',
#   'title': 'Farmers are hacking their tractors because of a repair ban (2018) '
#            '[video]',
#   'votes': 212},
#  {'link': 'https://blog.acolyer.org/2020/03/04/millions-of-tiny-databases/',
#   'title': 'Millions of Tiny Databases',
#   'votes': 211},
#  {'link': 'https://www.eenewseurope.com/news//60ghz-phased-array-antenna',
#   'title': 'Low-cost 60GHZ phased array antenna',
#   'votes': 194},
#  {'link': 'https://www.wgrz.com/article/news/local/inside-tesla-a-look-at-the-many-crates-of-equipment-delivered-to-the-south-buffalo-factory/71-341f2220-f2a6-4832-85a4-7c7a79171d89',
#   'title': '$50M worth of Tesla equipment sits unused in a Wheatfield '
#            'warehouse',
#   'votes': 187},
#  {'link': 'https://class.malware.re/',
#   'title': 'Malware Analysis and Reverse Engineering Course',
#   'votes': 175},
#  {'link': 'https://devblogs.microsoft.com/powershell/announcing-PowerShell-7-0/',
#   'title': 'PowerShell 7.0',
#   'votes': 167},
#  {'link': 'https://www.adamjuliangoldstein.com/blog/anxiety-algorithm/',
#   'title': 'Anxiety as an algorithm',
#   'votes': 157},
#  {'link': 'https://arstechnica.com/tech-policy/2020/02/trump-report-bizarrely-claims-net-neutrality-repeal-raised-incomes-50b-a-year/',
#   'title': 'Gov report bizarrely claims net neutrality repeal raised incomes '
#            '$50B a year',
#   'votes': 156},
#  {'link': 'https://en.wikipedia.org/wiki/Decision_fatigue',
#   'title': 'Decision fatigue',
#   'votes': 151},
#  {'link': 'https://www.sciencedirect.com/science/article/pii/S2352152X19309077',
#   'title': 'Aerogel from fruit biowaste produces ultracapacitors',
#   'votes': 148},
#  {'link': 'https://ericlippert.com/2020/02/27/hundred-year-mistakes/',
#   'title': 'Hundred Year Mistakes',
#   'votes': 135},
#  {'link': 'http://www.righto.com/2020/03/the-core-memory-inside-saturn-v-rockets.html',
#   'title': "The core memory inside a Saturn V rocket's computer",
#   'votes': 128},
#  {'link': 'https://worldwaterreserve.com/self-sufficiency/steps-to-start-homesteading/',
#   'title': 'Steps to start homesteading from an experienced grower',
#   'votes': 126},
#  {'link': 'item?id=22486031',
#   'title': 'Launch HN: Release (YC W20) – Staging environments made easy',
#   'votes': 120},
#  {'link': 'https://www.wsj.com/articles/heres-why-health-experts-want-to-stop-daylight-saving-time-11583340645',
#   'title': 'Health Experts Want to Stop Daylight-Saving Time',
#   'votes': 104}]

# %%
import pandas as pd

# %%
df= pd.DataFrame(create_custom_hn(mega_links, mega_subtext),columns=['link','title','votes'])

# %%
df
# Out:
#                                                  link  \
# 0   https://www.bleepingcomputer.com/news/software...
# 1   https://www.courdecassation.fr/IMG/20200304_ar...
# 2                   http://spotthedrowningchild.com/#
# 3   https://cloud.google.com/kubernetes-engine/pri...
# 4   https://www.law.nyu.edu/centers/engelberg/news...
# 5   https://georgestocker.com/2020/03/04/please-st...
# 6   https://www.quantamagazine.org/landmark-comput...
# 7                        https://waymo.com/waymo-via/
# 8   https://techcrunch.com/2020/03/04/anthony-leva...
# 9                               https://monitoror.com
# 10  https://africafeeds.com/2020/02/27/malawi-lega...
# 11        https://www.youtube.com/watch?v=F8JCh0owT4w
# 12  https://blog.acolyer.org/2020/03/04/millions-o...
# 13  https://www.eenewseurope.com/news//60ghz-phase...
# 14  https://www.wgrz.com/article/news/local/inside...
# 15                          https://class.malware.re/
# 16  https://devblogs.microsoft.com/powershell/anno...
# 17  https://www.adamjuliangoldstein.com/blog/anxie...
# 18  https://arstechnica.com/tech-policy/2020/02/tr...
# 19     https://en.wikipedia.org/wiki/Decision_fatigue
# 20  https://www.sciencedirect.com/science/article/...
# 21  https://ericlippert.com/2020/02/27/hundred-yea...
# 22  http://www.righto.com/2020/03/the-core-memory-...
# 23  https://worldwaterreserve.com/self-sufficiency...
# 24                                   item?id=22486031
# 25  https://www.wsj.com/articles/heres-why-health-...
#
#                                                 title  votes
# 0                 SETI@home shuts down after 21 years   1150
# 1   Highest French court reclassifies Uber drivers...    663
# 2                      Spot the Drowning Child (2015)    635
# 3   Google Kubernetes Engine is introducing a clus...    512
# 4   Explaining copyright broke the YouTube copyrig...    438
# 5                    Please stop recommending Gitflow    314
# 6   Landmark computer science proof cascades throu...    297
# 7                                           Waymo Via    284
# 8   Anthony Levandowski ordered to pay $179M to Go...    280
# 9   Show HN: Monitoror – Unified monitoring wallboard    271
# 10  Malawi legalises the growing, selling and expo...    216
# 11  Farmers are hacking their tractors because of ...    212
# 12                         Millions of Tiny Databases    211
# 13                Low-cost 60GHZ phased array antenna    194
# 14  $50M worth of Tesla equipment sits unused in a...    187
# 15    Malware Analysis and Reverse Engineering Course    175
# 16                                     PowerShell 7.0    167
# 17                            Anxiety as an algorithm    157
# 18  Gov report bizarrely claims net neutrality rep...    156
# 19                                   Decision fatigue    151
# 20  Aerogel from fruit biowaste produces ultracapa...    148
# 21                              Hundred Year Mistakes    135
# 22  The core memory inside a Saturn V rocket's com...    128
# 23  Steps to start homesteading from an experience...    126
# 24  Launch HN: Release (YC W20) – Staging environm...    120
# 25   Health Experts Want to Stop Daylight-Saving Time    104
